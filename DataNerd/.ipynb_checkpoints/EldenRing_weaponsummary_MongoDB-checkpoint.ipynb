# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import pymongo

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
db = client.eldenring
collection = db.weaponsummary

# %%
# URL of page to be scraped
url = 'https://eldenring.wiki.fextralife.com/Weapons+Comparison+Tables'
# retrieve page with the reqests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html5lib')

# %%
thead = soup.find('thead')
ths = thead.find_all('th')
keys = []
for th in ths:
    if th.text.strip() not in keys:
        keys.append(th.text.strip())
    else:
        keys.append("def-" + th.text.strip())
print(keys)
# Out:
# ['Weapon', 'Type', 'Phy', 'Mag', 'Fir', 'Lit', 'Hol', 'Cri', 'Sta', 'Str', 'Dex', 'Int', 'Fai', 'Arc', 'Any', 'def-Phy', 'def-Mag', 'def-Fir', 'def-Lit', 'def-Hol', 'Bst', 'Rst', 'Wgt', 'Upgrade']

# %%
# create function for replacing values for cleaning the data
def replace_values(list_to_replace, item_to_replace, item_to_replace_with):
    return [item_to_replace_with if item == item_to_replace else item for item in list_to_replace]

# %%
tbody = soup.find('tbody')
trs = tbody.find_all('tr')
for tr in trs:
    data = []
    post ={}
    tds = tr.find_all('td')
    for td in tds:
        data.append(td.text)
        data = replace_values(data, "-", 0)
    for key in keys:
        for value in data:
            post[key] = value
            data.remove(value)
            break
    #collection.insert_one(post)
    print(post)
# Out:
# {'Weapon': 'Academy Glintstone Staff', 'Type': 'Glintstone Staff', 'Phy': '43', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'D', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Alabaster Lord's Sword", 'Type': 'Greatsword', 'Phy': '313', 'Mag': '93', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '126', 'Str': 'B', 'Dex': 'D', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '41', 'def-Mag': '33', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': '33', 'Rst': '19', 'Wgt': '8', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Albinauric Bow', 'Type': 'Bow', 'Phy': '200', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '60', 'Str': 'E', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': '0', 'Rst': '0', 'Wgt': '4.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Albinauric Staff', 'Type': 'Glintstone Staff', 'Phy': '29', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '38', 'Str': 'D', 'Dex': '0', 'Int': 'B', 'Fai': '0', 'Arc': 'S', 'Any': '0', 'def-Phy': '23', 'def-Mag': '14', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '14', 'Bst': '14', 'Rst': '9', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Antspur Rapier', 'Type': 'Thrusting Sword', 'Phy': '240', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '62', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '25', 'Rst': '10', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Arbalest', 'Type': 'Crossbow', 'Phy': '308', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '68', 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': '0', 'Rst': '0', 'Wgt': '6', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Astrologer's Staff", 'Type': 'Glintstone Staff', 'Phy': '43', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'D', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Axe of Godfrey', 'Type': 'Colossal Weapon', 'Phy': '404', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '150', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '60', 'def-Mag': '45', 'def-Fir': '45', 'def-Lit': '45', 'def-Hol': '45', 'Bst': '40', 'Rst': '25', 'Wgt': '18', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Axe of Godrick', 'Type': 'Greataxe', 'Phy': '347', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '150', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '35', 'Rst': '20', 'Wgt': '11', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Azur's Glintstone Staff", 'Type': 'Glintstone Staff', 'Phy': '58', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '42', 'Str': 'C', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '4', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Bandit's Curved Sword", 'Type': 'Curved Sword', 'Phy': '289', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '98', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': '36', 'Rst': '12', 'Wgt': '5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Banished Knight's Greatsword", 'Type': 'Greatsword', 'Phy': '347', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '132', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': '43', 'Rst': '21', 'Wgt': '10', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Banished Knight's Halberd", 'Type': 'Halberd', 'Phy': '306', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '122', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '42', 'Rst': '15', 'Wgt': '8', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Bastard Sword', 'Type': 'Greatsword', 'Phy': '338', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '126', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '42', 'Rst': '20', 'Wgt': '9', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Bastard's Stars", 'Type': 'Flail', 'Phy': '159', 'Mag': '191', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '106', 'Str': 'E', 'Dex': 'C', 'Int': 'B', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '32', 'def-Mag': '48', 'def-Fir': '24', 'def-Lit': '24', 'def-Hol': '24', 'Bst': '20', 'Rst': '15', 'Wgt': '5.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Battle Axe', 'Type': 'Axe', 'Phy': '301', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '112', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '37', 'Rst': '15', 'Wgt': '4.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Battle Hammer', 'Type': 'Great Hammer', 'Phy': '320', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '194', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': '43', 'Rst': '21', 'Wgt': '10', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Beast-Repellent Torch', 'Type': 'Torch', 'Phy': '142', 'Mag': '0', 'Fir': '254', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '94', 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '23', 'def-Mag': '17', 'def-Fir': '28', 'def-Lit': '17', 'def-Hol': '17', 'Bst': '22', 'Rst': '14', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Beastclaw Greathammer', 'Type': 'Great Hammer', 'Phy': '284', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '183', 'Cri': '100', 'Sta': '182', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '45', 'Bst': '35', 'Rst': '20', 'Wgt': '9', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Beastman's Cleaver", 'Type': 'Curved Greatsword', 'Phy': '350', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '164', 'Str': 'B', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '62', 'def-Mag': '43', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '43', 'Bst': '51', 'Rst': '25', 'Wgt': '16.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Beastman's Curved Sword", 'Type': 'Curved Sword', 'Phy': '276', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '98', 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '44', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': '32', 'Rst': '11', 'Wgt': '4', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Black Bow', 'Type': 'Bow', 'Phy': '171', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '60', 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': '0', 'Rst': '0', 'Wgt': '4', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Black Knife', 'Type': 'Dagger', 'Phy': '161', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '159', 'Cri': '110', 'Sta': '56', 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '26', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '42', 'Bst': '15', 'Rst': '10', 'Wgt': '2', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Blade of Calling', 'Type': 'Dagger', 'Phy': '173', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '105', 'Cri': '110', 'Sta': '56', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '31', 'def-Mag': '18', 'def-Fir': '18', 'def-Lit': '18', 'def-Hol': '30', 'Bst': '15', 'Rst': '10', 'Wgt': '1.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Blasphemous Blade', 'Type': 'Greatsword', 'Phy': '296', 'Mag': '0', 'Fir': '191', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '138', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '56', 'def-Mag': '39', 'def-Fir': '54', 'def-Lit': '39', 'def-Hol': '39', 'Bst': '42', 'Rst': '24', 'Wgt': '13.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Bloodhound Claws', 'Type': 'Claw', 'Phy': '230', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '110', 'Sta': '78', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(60)', 'def-Phy': '38', 'def-Mag': '22', 'def-Fir': '22', 'def-Lit': '22', 'def-Hol': '22', 'Bst': '26', 'Rst': '11', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Bloodhound's Fang", 'Type': 'Curved Greatsword', 'Phy': '345', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '122', 'Str': 'C', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': '36', 'Rst': '21', 'Wgt': '11.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Bloodstained Dagger', 'Type': 'Dagger', 'Phy': '198', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '110', 'Sta': '60', 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(38)', 'def-Phy': '36', 'def-Mag': '21', 'def-Fir': '21', 'def-Lit': '21', 'def-Hol': '21', 'Bst': '18', 'Rst': '10', 'Wgt': '2', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Bloody Helice', 'Type': 'Heavy Thrusting Sword', 'Phy': '296', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '94', 'Str': 'E', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': 'B', 'Any': '(55)', 'def-Phy': '57', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '40', 'def-Hol': '40', 'Bst': '34', 'Rst': '17', 'Wgt': '8', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Bolt of Gransax', 'Type': 'Spear', 'Phy': '240', 'Mag': '0', 'Fir': '0', 'Lit': '154', 'Hol': '0', 'Cri': '100', 'Sta': '88', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '60', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '47', 'def-Hol': '31', 'Bst': '40', 'Rst': '20', 'Wgt': '8.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Brick Hammer', 'Type': 'Great Hammer', 'Phy': '298', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '218', 'Str': 'A', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '57', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '40', 'def-Hol': '40', 'Bst': '48', 'Rst': '23', 'Wgt': '12.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Broadsword', 'Type': 'Straight Sword', 'Phy': '286', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '94', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '37', 'Rst': '15', 'Wgt': '4', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Butchering Knife', 'Type': 'Greataxe', 'Phy': '328', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '150', 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '45', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '37', 'Rst': '18', 'Wgt': '8.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Caestus', 'Type': 'Fist', 'Phy': '220', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '100', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '20', 'def-Fir': '20', 'def-Lit': '20', 'def-Hol': '20', 'Bst': '24', 'Rst': '10', 'Wgt': '1.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Cane Sword', 'Type': 'Straight Sword', 'Phy': '235', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '86', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '41', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': '32', 'Rst': '13', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Carian Glintblade Staff', 'Type': 'Glintstone Staff', 'Phy': '38', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '38', 'Str': 'D', 'Dex': 'D', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '23', 'def-Mag': '14', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '14', 'Bst': '14', 'Rst': '9', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Carian Glintstone Staff', 'Type': 'Glintstone Staff', 'Phy': '43', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'D', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Carian Knight's Sword", 'Type': 'Straight Sword', 'Phy': '215', 'Mag': '215', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '90', 'Str': 'C', 'Dex': 'D', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '36', 'def-Mag': '52', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '26', 'Bst': '31', 'Rst': '15', 'Wgt': '4', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Carian Regal Scepter', 'Type': 'Glintstone Staff', 'Phy': '58', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'D', 'Dex': 'D', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '3', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Celebrant's Cleaver", 'Type': 'Axe', 'Phy': '291', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '112', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '37', 'Rst': '15', 'Wgt': '4.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Celebrant's Rib-Rake", 'Type': 'Spear', 'Phy': '267', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '68', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '40', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '25', 'Bst': '36', 'Rst': '15', 'Wgt': '5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Celebrant's Sickle", 'Type': 'Dagger', 'Phy': '193', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '56', 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '20', 'def-Fir': '20', 'def-Lit': '20', 'def-Hol': '20', 'Bst': '18', 'Rst': '10', 'Wgt': '1.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Celebrant's Skull", 'Type': 'Great Hammer', 'Phy': '338', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '182', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '34', 'def-Fir': '34', 'def-Lit': '34', 'def-Hol': '34', 'Bst': '40', 'Rst': '19', 'Wgt': '8.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Chainlink Flail', 'Type': 'Flail', 'Phy': '267', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '122', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '43', 'def-Mag': '28', 'def-Fir': '28', 'def-Lit': '28', 'def-Hol': '28', 'Bst': '28', 'Rst': '18', 'Wgt': '8', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Cinquedea', 'Type': 'Dagger', 'Phy': '240', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '68', 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '43', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '25', 'Bst': '18', 'Rst': '12', 'Wgt': '3.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Cipher Pata', 'Type': 'Fist', 'Phy': '0', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '208', 'Cri': '100', 'Sta': '90', 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': 'A', 'Arc': '0', 'Any': '0', 'def-Phy': '9', 'def-Mag': '14', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '61', 'Bst': '19', 'Rst': '9', 'Wgt': '0', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Clawmark Seal', 'Type': 'Sacred Seal', 'Phy': '54', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'B', 'Dex': '0', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '1.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Clayman's Harpoon", 'Type': 'Spear', 'Phy': '242', 'Mag': '156', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '80', 'Str': 'C', 'Dex': 'E', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '49', 'def-Mag': '38', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '25', 'Bst': '39', 'Rst': '16', 'Wgt': '5.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Claymore', 'Type': 'Greatsword', 'Phy': '338', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '126', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '42', 'Rst': '20', 'Wgt': '9', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Cleanrot Knight's Sword", 'Type': 'Thrusting Sword', 'Phy': '267', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '66', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '51', 'def-Mag': '34', 'def-Fir': '34', 'def-Lit': '34', 'def-Hol': '34', 'Bst': '27', 'Rst': '11', 'Wgt': '4', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Cleanrot Spear', 'Type': 'Spear', 'Phy': '249', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '161', 'Cri': '100', 'Sta': '80', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '49', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '38', 'Bst': '33', 'Rst': '16', 'Wgt': '5.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Clinging Bone', 'Type': 'Fist', 'Phy': '196', 'Mag': '58', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '94', 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': 'C', 'Any': '0', 'def-Phy': '31', 'def-Mag': '36', 'def-Fir': '17', 'def-Lit': '17', 'def-Hol': '17', 'Bst': '21', 'Rst': '10', 'Wgt': '3', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Club', 'Type': 'Hammer', 'Phy': '252', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '102', 'Str': 'B', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '41', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': '32', 'Rst': '13', 'Wgt': '3.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Coded Sword', 'Type': 'Straight Sword', 'Phy': '0', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '208', 'Cri': '100', 'Sta': '76', 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': 'A', 'Arc': '0', 'Any': '0', 'def-Phy': '13', 'def-Mag': '22', 'def-Fir': '22', 'def-Lit': '22', 'def-Hol': '58', 'Bst': '27', 'Rst': '13', 'Wgt': '2.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Commander's Standard", 'Type': 'Halberd', 'Phy': '338', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '136', 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '58', 'def-Mag': '41', 'def-Fir': '41', 'def-Lit': '41', 'def-Hol': '41', 'Bst': '41', 'Rst': '17', 'Wgt': '11.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Composite Bow', 'Type': 'Light Bow', 'Phy': '159', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'E', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': '0', 'Rst': '0', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Cranial Vessel Candlestand', 'Type': 'Great Hammer', 'Phy': '240', 'Mag': '0', 'Fir': '240', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '190', 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '54', 'def-Mag': '37', 'def-Fir': '51', 'def-Lit': '37', 'def-Hol': '37', 'Bst': '40', 'Rst': '23', 'Wgt': '12.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Crepus's Black-Key Crossbow", 'Type': 'Crossbow', 'Phy': '238', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '64', 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': '0', 'Rst': '0', 'Wgt': '5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Crescent Moon Axe', 'Type': 'Greataxe', 'Phy': '357', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '156', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': '43', 'Rst': '21', 'Wgt': '12.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Cross-Naginata', 'Type': 'Spear', 'Phy': '298', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '88', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '52', 'def-Mag': '32', 'def-Fir': '32', 'def-Lit': '32', 'def-Hol': '32', 'Bst': '46', 'Rst': '19', 'Wgt': '8', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Crystal Knife', 'Type': 'Dagger', 'Phy': '200', 'Mag': '129', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '62', 'Str': 'C', 'Dex': 'D', 'Int': 'B', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '32', 'def-Mag': '31', 'def-Fir': '18', 'def-Lit': '18', 'def-Hol': '18', 'Bst': '18', 'Rst': '10', 'Wgt': '2', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Crystal Spear', 'Type': 'Spear', 'Phy': '269', 'Mag': '80', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '80', 'Str': 'D', 'Dex': 'B', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '33', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '26', 'Bst': '33', 'Rst': '16', 'Wgt': '5.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Crystal Staff', 'Type': 'Glintstone Staff', 'Phy': '75', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '46', 'Str': 'C', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '28', 'def-Mag': '17', 'def-Fir': '17', 'def-Lit': '17', 'def-Hol': '17', 'Bst': '17', 'Rst': '11', 'Wgt': '4.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Crystal Sword', 'Type': 'Straight Sword', 'Phy': '259', 'Mag': '166', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '98', 'Str': 'C', 'Dex': 'D', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '44', 'def-Mag': '44', 'def-Fir': '30', 'def-Lit': '30', 'def-Hol': '30', 'Bst': '33', 'Rst': '16', 'Wgt': '4.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Curved Club', 'Type': 'Hammer', 'Phy': '279', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '106', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '45', 'def-Mag': '30', 'def-Fir': '30', 'def-Lit': '30', 'def-Hol': '30', 'Bst': '36', 'Rst': '15', 'Wgt': '5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Curved Great Club', 'Type': 'Great Hammer', 'Phy': '355', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '194', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': '43', 'Rst': '21', 'Wgt': '10', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Dagger', 'Type': 'Dagger', 'Phy': '181', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '130', 'Sta': '60', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '20', 'def-Fir': '20', 'def-Lit': '20', 'def-Hol': '20', 'Bst': '18', 'Rst': '10', 'Wgt': '1.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Dark Moon Greatsword', 'Type': 'Greatsword', 'Phy': '200', 'Mag': '240', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '126', 'Str': 'D', 'Dex': 'D', 'Int': 'B', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '42', 'def-Mag': '63', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '36', 'Rst': '21', 'Wgt': '10', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Death Ritual Spear', 'Type': 'Spear', 'Phy': '242', 'Mag': '156', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '110', 'Sta': '84', 'Str': 'D', 'Dex': 'B', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '54', 'def-Mag': '42', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': '36', 'Rst': '18', 'Wgt': '6.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Death's Poker", 'Type': 'Greatsword', 'Phy': '301', 'Mag': '88', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '116', 'Str': 'C', 'Dex': 'B', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '(65)', 'def-Phy': '46', 'def-Mag': '39', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': '33', 'Rst': '19', 'Wgt': '8.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Demi-Human Queen's Staff", 'Type': 'Glintstone Staff', 'Phy': '54', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'C', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Devourer's Scepter", 'Type': 'Great Hammer', 'Phy': '262', 'Mag': '0', 'Fir': '169', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '154', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '45', 'def-Lit': '33', 'def-Hol': '33', 'Bst': '35', 'Rst': '20', 'Wgt': '11.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Digger's Staff", 'Type': 'Glintstone Staff', 'Phy': '66', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '46', 'Str': 'C', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '28', 'def-Mag': '17', 'def-Fir': '17', 'def-Lit': '17', 'def-Hol': '17', 'Bst': '17', 'Rst': '11', 'Wgt': '4.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Dismounter', 'Type': 'Curved Greatsword', 'Phy': '338', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '122', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '42', 'Rst': '20', 'Wgt': '10', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Dragon Communion Seal', 'Type': 'Sacred Seal', 'Phy': '61', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': 'B', 'Arc': 'S', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '0', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Dragon Greatclaw', 'Type': 'Colossal Weapon', 'Phy': '294', 'Mag': '0', 'Fir': '0', 'Lit': '191', 'Hol': '0', 'Cri': '100', 'Sta': '150', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '52', 'def-Hol': '40', 'Bst': '38', 'Rst': '23', 'Wgt': '16', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Dragon Halberd', 'Type': 'Halberd', 'Phy': '330', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '136', 'Str': 'B', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '37', 'def-Fir': '37', 'def-Lit': '50', 'def-Hol': '37', 'Bst': '39', 'Rst': '16', 'Wgt': '10.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Dragon King's Cragblade", 'Type': 'Heavy Thrusting Sword', 'Phy': '225', 'Mag': '0', 'Fir': '0', 'Lit': '144', 'Hol': '0', 'Cri': '100', 'Sta': '98', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '46', 'def-Mag': '32', 'def-Fir': '32', 'def-Lit': '46', 'def-Hol': '32', 'Bst': '34', 'Rst': '17', 'Wgt': '8', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Dragonscale Blade', 'Type': 'Katana', 'Phy': '269', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '90', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '50', 'def-Hol': '25', 'Bst': '30', 'Rst': '15', 'Wgt': '5.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Duelist Greataxe', 'Type': 'Colossal Weapon', 'Phy': '416', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '156', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '63', 'def-Mag': '47', 'def-Fir': '47', 'def-Lit': '47', 'def-Hol': '47', 'Bst': '50', 'Rst': '26', 'Wgt': '20', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Eclipse Shotel', 'Type': 'Curved Sword', 'Phy': '188', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '188', 'Cri': '100', 'Sta': '94', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '35', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '50', 'Bst': '25', 'Rst': '10', 'Wgt': '3', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Eleonora's Poleblade", 'Type': 'Twinblade', 'Phy': '176', 'Mag': '0', 'Fir': '176', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '84', 'Str': 'E', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': 'D', 'Any': '(83)', 'def-Phy': '33', 'def-Mag': '23', 'def-Fir': '47', 'def-Lit': '23', 'def-Hol': '23', 'Bst': '28', 'Rst': '14', 'Wgt': '6', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Envoy's Greathorn", 'Type': 'Colossal Weapon', 'Phy': '296', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '191', 'Cri': '100', 'Sta': '202', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '43', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '55', 'Bst': '40', 'Rst': '25', 'Wgt': '19.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Envoy's Horn", 'Type': 'Hammer', 'Phy': '235', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '151', 'Cri': '100', 'Sta': '106', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '38', 'def-Mag': '26', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '38', 'Bst': '28', 'Rst': '14', 'Wgt': '4', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Envoy's Long Horn", 'Type': 'Great Hammer', 'Phy': '294', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '191', 'Cri': '100', 'Sta': '154', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '44', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '42', 'Bst': '33', 'Rst': '19', 'Wgt': '9.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Erdsteel Dagger', 'Type': 'Dagger', 'Phy': '164', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '110', 'Sta': '60', 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '36', 'def-Mag': '21', 'def-Fir': '21', 'def-Lit': '21', 'def-Hol': '21', 'Bst': '18', 'Rst': '10', 'Wgt': '2', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Erdtree Bow', 'Type': 'Bow', 'Phy': '98', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '122', 'Cri': '100', 'Sta': '60', 'Str': 'E', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': '0', 'Rst': '0', 'Wgt': '4', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Erdtree Greatbow', 'Type': 'Greatbow', 'Phy': '147', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '159', 'Cri': '100', 'Sta': '150', 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': '0', 'Rst': '0', 'Wgt': '11', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Erdtree Seal', 'Type': 'Sacred Seal', 'Phy': '61', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '36', 'Cri': '100', 'Sta': '40', 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': 'S', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '0', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Estoc', 'Type': 'Thrusting Sword', 'Phy': '262', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '66', 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '54', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': '28', 'Rst': '12', 'Wgt': '4.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Executioner's Greataxe", 'Type': 'Greataxe', 'Phy': '367', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '115', 'Sta': '172', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '57', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '40', 'def-Hol': '40', 'Bst': '48', 'Rst': '23', 'Wgt': '15', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Falchion', 'Type': 'Curved Sword', 'Phy': '267', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '94', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '42', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '31', 'Rst': '10', 'Wgt': '3.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Fallingstar Beast Jaw', 'Type': 'Colossal Weapon', 'Phy': '320', 'Mag': '208', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '180', 'Str': 'C', 'Dex': 'C', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '55', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '43', 'Bst': '40', 'Rst': '25', 'Wgt': '21.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Family Heads', 'Type': 'Flail', 'Phy': '213', 'Mag': '137', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '106', 'Str': 'D', 'Dex': 'B', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '37', 'def-Mag': '36', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '26', 'Bst': '20', 'Rst': '15', 'Wgt': '5.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Finger Seal', 'Type': 'Sacred Seal', 'Phy': '43', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'D', 'Dex': '0', 'Int': '0', 'Fai': 'S', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '1.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Flail', 'Type': 'Flail', 'Phy': '267', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '112', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '36', 'def-Mag': '24', 'def-Fir': '24', 'def-Lit': '24', 'def-Hol': '24', 'Bst': '24', 'Rst': '15', 'Wgt': '5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Flamberge', 'Type': 'Greatsword', 'Phy': '316', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '118', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '42', 'Rst': '20', 'Wgt': '10', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Flowing Curved Sword', 'Type': 'Curved Sword', 'Phy': '267', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '94', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '42', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '31', 'Rst': '10', 'Wgt': '3.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Forked Greatsword', 'Type': 'Greatsword', 'Phy': '303', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '112', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': '39', 'Rst': '19', 'Wgt': '9', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Forked Hatchet', 'Type': 'Axe', 'Phy': '247', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '106', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '40', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': '32', 'Rst': '13', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Frenzied Flame Seal', 'Type': 'Sacred Seal', 'Phy': '61', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'C', 'Dex': 'C', 'Int': 'C', 'Fai': 'B', 'Arc': '0', 'Any': '(55)', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '0', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Frozen Needle', 'Type': 'Thrusting Sword', 'Phy': '242', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '60', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(60)', 'def-Phy': '40', 'def-Mag': '40', 'def-Fir': '28', 'def-Lit': '28', 'def-Hol': '28', 'Bst': '20', 'Rst': '10', 'Wgt': '2.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Full Moon Crossbow', 'Type': 'Crossbow', 'Phy': '175', 'Mag': '175', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '60', 'Str': '0', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '0', 'def-Mag': '0', 'def-Fir': '0', 'def-Lit': '0', 'def-Hol': '0', 'Bst': '0', 'Rst': '0', 'Wgt': '4', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Gargoyle's Black Axe", 'Type': 'Greataxe', 'Phy': '245', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '294', 'Cri': '100', 'Sta': '150', 'Str': 'C', 'Dex': 'E', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '36', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '54', 'Bst': '31', 'Rst': '18', 'Wgt': '8.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Gargoyle's Black Blades", 'Type': 'Twinblade', 'Phy': '198', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '237', 'Cri': '100', 'Sta': '100', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '32', 'def-Mag': '26', 'def-Fir': '26', 'def-Lit': '26', 'def-Hol': '59', 'Bst': '32', 'Rst': '16', 'Wgt': '8.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Gargoyle's Black Halberd", 'Type': 'Halberd', 'Phy': '252', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '301', 'Cri': '100', 'Sta': '152', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '72', 'Bst': '42', 'Rst': '18', 'Wgt': '12', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Gargoyle's Blackblade", 'Type': 'Greatsword', 'Phy': '249', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '298', 'Cri': '100', 'Sta': '138', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '44', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '66', 'Bst': '38', 'Rst': '22', 'Wgt': '11.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Gargoyle's Great Axe", 'Type': 'Greataxe', 'Phy': '301', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '150', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '45', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '37', 'Rst': '18', 'Wgt': '8.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Gargoyle's Greatsword", 'Type': 'Greatsword', 'Phy': '325', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '138', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '38', 'def-Fir': '38', 'def-Lit': '38', 'def-Hol': '38', 'Bst': '45', 'Rst': '22', 'Wgt': '11.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Gargoyle's Halberd", 'Type': 'Halberd', 'Phy': '320', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '152', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '60', 'def-Mag': '42', 'def-Fir': '42', 'def-Lit': '42', 'def-Hol': '42', 'Bst': '50', 'Rst': '18', 'Wgt': '12', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Gargoyle's Twinblade", 'Type': 'Twinblade', 'Phy': '301', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '100', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '32', 'def-Fir': '32', 'def-Lit': '32', 'def-Hol': '32', 'Bst': '38', 'Rst': '16', 'Wgt': '8.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Gelmir Glintstone Staff', 'Type': 'Glintstone Staff', 'Phy': '50', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '38', 'Str': 'D', 'Dex': '0', 'Int': 'B', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '23', 'def-Mag': '14', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '14', 'Bst': '14', 'Rst': '9', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Ghiza's Wheel", 'Type': 'Colossal Weapon', 'Phy': '382', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '184', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(70)', 'def-Phy': '58', 'def-Mag': '43', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '43', 'Bst': '39', 'Rst': '24', 'Wgt': '19', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Ghostflame Torch', 'Type': 'Torch', 'Phy': '122', 'Mag': '220', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '104', 'Str': 'D', 'Dex': 'D', 'Int': 'C', 'Fai': '0', 'Arc': '0', 'Any': '(65)', 'def-Phy': '21', 'def-Mag': '42', 'def-Fir': '13', 'def-Lit': '13', 'def-Hol': '13', 'Bst': '22', 'Rst': '14', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Giant's Red Braid", 'Type': 'Whip', 'Phy': '200', 'Mag': '0', 'Fir': '129', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '88', 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '24', 'def-Mag': '12', 'def-Fir': '26', 'def-Lit': '12', 'def-Hol': '12', 'Bst': '15', 'Rst': '10', 'Wgt': '2.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Giant's Seal", 'Type': 'Sacred Seal', 'Phy': '43', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'D', 'Dex': '0', 'Int': '0', 'Fai': 'S', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '1.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Giant-Crusher', 'Type': 'Colossal Weapon', 'Phy': '379', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '224', 'Str': 'B', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '70', 'def-Mag': '52', 'def-Fir': '52', 'def-Lit': '52', 'def-Hol': '52', 'Bst': '56', 'Rst': '29', 'Wgt': '26.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Glaive', 'Type': 'Halberd', 'Phy': '323', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '128', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '38', 'def-Fir': '38', 'def-Lit': '38', 'def-Hol': '38', 'Bst': '45', 'Rst': '16', 'Wgt': '10', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Glintstone Kris', 'Type': 'Dagger', 'Phy': '139', 'Mag': '166', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '110', 'Sta': '56', 'Str': 'E', 'Dex': 'C', 'Int': 'C', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '23', 'def-Mag': '45', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '14', 'Bst': '15', 'Rst': '10', 'Wgt': '1.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Glintstone Staff', 'Type': 'Glintstone Staff', 'Phy': '43', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'D', 'Dex': '0', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Godskin Peeler', 'Type': 'Twinblade', 'Phy': '296', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '90', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '37', 'Rst': '15', 'Wgt': '8', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Godskin Stitcher', 'Type': 'Heavy Thrusting Sword', 'Phy': '311', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '94', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '38', 'def-Fir': '38', 'def-Lit': '38', 'def-Hol': '38', 'Bst': '39', 'Rst': '16', 'Wgt': '7', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Godslayer's Greatsword", 'Type': 'Colossal Sword', 'Phy': '291', 'Mag': '0', 'Fir': '188', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '120', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '49', 'def-Mag': '38', 'def-Fir': '49', 'def-Lit': '38', 'def-Hol': '38', 'Bst': '36', 'Rst': '22', 'Wgt': '17.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Godslayer's Seal", 'Type': 'Sacred Seal', 'Phy': '43', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': 'D', 'Dex': '0', 'Int': '0', 'Fai': 'S', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '1.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Golden Epitaph', 'Type': 'Straight Sword', 'Phy': '208', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '208', 'Cri': '100', 'Sta': '90', 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '40', 'Bst': '30', 'Rst': '15', 'Wgt': '3.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Golden Halberd', 'Type': 'Halberd', 'Phy': '328', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '213', 'Cri': '100', 'Sta': '152', 'Str': 'B', 'Dex': 'D', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '58', 'def-Mag': '41', 'def-Fir': '41', 'def-Lit': '41', 'def-Hol': '56', 'Bst': '43', 'Rst': '18', 'Wgt': '13.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Golden Order Greatsword', 'Type': 'Greatsword', 'Phy': '210', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '252', 'Cri': '100', 'Sta': '118', 'Str': 'E', 'Dex': 'D', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '40', 'def-Mag': '30', 'def-Fir': '30', 'def-Lit': '30', 'def-Hol': '60', 'Bst': '35', 'Rst': '20', 'Wgt': '10', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Golden Order Seal', 'Type': 'Sacred Seal', 'Phy': '58', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '40', 'Str': '0', 'Dex': '0', 'Int': 'A', 'Fai': 'A', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '15', 'Rst': '10', 'Wgt': '0', 'Upgrade': 'Somber Smithing Stones'}
# ...
# {'Weapon': 'Spiked Spear', 'Type': 'Spear', 'Phy': '294', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '80', 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '46', 'def-Mag': '28', 'def-Fir': '28', 'def-Lit': '28', 'def-Hol': '28', 'Bst': '40', 'Rst': '17', 'Wgt': '6', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "St. Trina's Torch", 'Type': 'Torch', 'Phy': '124', 'Mag': '0', 'Fir': '222', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '104', 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '(72)', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '40', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '20', 'Rst': '15', 'Wgt': '3', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Staff of Loss', 'Type': 'Glintstone Staff', 'Phy': '38', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '38', 'Str': 'D', 'Dex': 'D', 'Int': 'S', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '23', 'def-Mag': '14', 'def-Fir': '14', 'def-Lit': '14', 'def-Hol': '14', 'Bst': '14', 'Rst': '9', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Staff of the Avatar', 'Type': 'Colossal Weapon', 'Phy': '276', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '178', 'Cri': '100', 'Sta': '210', 'Str': 'A', 'Dex': 'D', 'Int': '0', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '57', 'def-Mag': '45', 'def-Fir': '45', 'def-Lit': '45', 'def-Hol': '57', 'Bst': '42', 'Rst': '26', 'Wgt': '20', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Staff of the Guilty', 'Type': 'Glintstone Staff', 'Phy': '66', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '46', 'Str': 'C', 'Dex': '0', 'Int': '0', 'Fai': 'S', 'Arc': '0', 'Any': '(45)', 'def-Phy': '28', 'def-Mag': '17', 'def-Fir': '17', 'def-Lit': '17', 'def-Hol': '17', 'Bst': '17', 'Rst': '11', 'Wgt': '4.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Star Fist', 'Type': 'Fist', 'Phy': '257', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '112', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(45)', 'def-Phy': '41', 'def-Mag': '23', 'def-Fir': '23', 'def-Lit': '23', 'def-Hol': '23', 'Bst': '27', 'Rst': '11', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Starscourge Greatsword', 'Type': 'Colossal Sword', 'Phy': '316', 'Mag': '203', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '156', 'Str': 'B', 'Dex': 'D', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '49', 'def-Mag': '47', 'def-Fir': '34', 'def-Lit': '34', 'def-Hol': '34', 'Bst': '42', 'Rst': '26', 'Wgt': '20', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Steel-Wire Torch', 'Type': 'Torch', 'Phy': '149', 'Mag': '0', 'Fir': '267', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '104', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '18', 'def-Fir': '30', 'def-Lit': '18', 'def-Hol': '18', 'Bst': '24', 'Rst': '15', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Stone Club', 'Type': 'Hammer', 'Phy': '298', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '130', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '42', 'Rst': '17', 'Wgt': '7', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Stormhawk Axe', 'Type': 'Axe', 'Phy': '318', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '116', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '49', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': '33', 'Rst': '16', 'Wgt': '5.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Sword of Milos', 'Type': 'Greatsword', 'Phy': '345', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '126', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '52', 'def-Mag': '36', 'def-Fir': '36', 'def-Lit': '36', 'def-Hol': '36', 'Bst': '36', 'Rst': '21', 'Wgt': '10', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Sword of Night and Flame', 'Type': 'Straight Sword', 'Phy': '213', 'Mag': '137', 'Fir': '137', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '94', 'Str': 'D', 'Dex': 'D', 'Int': 'B', 'Fai': 'B', 'Arc': '0', 'Any': '0', 'def-Phy': '36', 'def-Mag': '42', 'def-Fir': '42', 'def-Lit': '26', 'def-Hol': '26', 'Bst': '31', 'Rst': '15', 'Wgt': '4', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Sword of St. Trina', 'Type': 'Straight Sword', 'Phy': '262', 'Mag': '78', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '90', 'Str': 'D', 'Dex': 'C', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '(66)', 'def-Phy': '39', 'def-Mag': '33', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': '28', 'Rst': '14', 'Wgt': '3', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Thorned Whip', 'Type': 'Whip', 'Phy': '249', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '84', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(50)', 'def-Phy': '26', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '18', 'Rst': '10', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Torch', 'Type': 'Torch', 'Phy': '132', 'Mag': '0', 'Fir': '237', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '84', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '21', 'def-Mag': '15', 'def-Fir': '25', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '20', 'Rst': '12', 'Wgt': '1.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Torchpole', 'Type': 'Spear', 'Phy': '254', 'Mag': '0', 'Fir': '75', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '72', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '48', 'def-Mag': '26', 'def-Fir': '33', 'def-Lit': '26', 'def-Hol': '26', 'Bst': '39', 'Rst': '16', 'Wgt': '6', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Treespear', 'Type': 'Great Spear', 'Phy': '298', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '193', 'Cri': '100', 'Sta': '122', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '48', 'Bst': '44', 'Rst': '21', 'Wgt': '9.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Troll Knight's Sword", 'Type': 'Colossal Sword', 'Phy': '303', 'Mag': '196', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '150', 'Str': 'C', 'Dex': 'C', 'Int': 'D', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '55', 'def-Mag': '55', 'def-Fir': '43', 'def-Lit': '43', 'def-Hol': '43', 'Bst': '40', 'Rst': '25', 'Wgt': '18', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': "Troll's Golden Sword", 'Type': 'Colossal Sword', 'Phy': '379', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '152', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '61', 'def-Mag': '46', 'def-Fir': '46', 'def-Lit': '46', 'def-Hol': '46', 'Bst': '49', 'Rst': '25', 'Wgt': '19', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Troll's Hammer", 'Type': 'Colossal Weapon', 'Phy': '374', 'Mag': '0', 'Fir': '110', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '184', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': 'D', 'Arc': '0', 'Any': '0', 'def-Phy': '52', 'def-Mag': '41', 'def-Fir': '46', 'def-Lit': '41', 'def-Hol': '41', 'Bst': '44', 'Rst': '23', 'Wgt': '16', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Twinblade', 'Type': 'Twinblade', 'Phy': '291', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '90', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '45', 'def-Mag': '30', 'def-Fir': '30', 'def-Lit': '30', 'def-Hol': '30', 'Bst': '36', 'Rst': '15', 'Wgt': '7', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Twinned Knight Swords', 'Type': 'Twinblade', 'Phy': '298', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '94', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '47', 'def-Mag': '31', 'def-Fir': '31', 'def-Lit': '31', 'def-Hol': '31', 'Bst': '37', 'Rst': '15', 'Wgt': '8', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Uchigatana', 'Type': 'Katana', 'Phy': '281', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '90', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(45)', 'def-Phy': '45', 'def-Mag': '30', 'def-Fir': '30', 'def-Lit': '30', 'def-Hol': '30', 'Bst': '36', 'Rst': '15', 'Wgt': '5.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Urumi', 'Type': 'Whip', 'Phy': '247', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '92', 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '27', 'def-Mag': '16', 'def-Fir': '16', 'def-Lit': '16', 'def-Hol': '16', 'Bst': '19', 'Rst': '11', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Varre's Bouquet", 'Type': 'Hammer', 'Phy': '112', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '100', 'Str': 'E', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': 'B', 'Any': '(65)', 'def-Phy': '38', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '25', 'Bst': '25', 'Rst': '12', 'Wgt': '2', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Venomous Fang', 'Type': 'Claw', 'Phy': '225', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '78', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(72)', 'def-Phy': '36', 'def-Mag': '21', 'def-Fir': '21', 'def-Lit': '21', 'def-Hol': '21', 'Bst': '25', 'Rst': '10', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Veteran's Prosthesis", 'Type': 'Fist', 'Phy': '203', 'Mag': '0', 'Fir': '0', 'Lit': '129', 'Hol': '0', 'Cri': '100', 'Sta': '110', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '30', 'def-Mag': '20', 'def-Fir': '20', 'def-Lit': '48', 'def-Hol': '20', 'Bst': '24', 'Rst': '12', 'Wgt': '4', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Vulgar Militia Saw', 'Type': 'Halberd', 'Phy': '308', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '128', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(55)', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '42', 'Rst': '15', 'Wgt': '8', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Vulgar Militia Shotel', 'Type': 'Halberd', 'Phy': '296', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '128', 'Str': 'E', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '42', 'Rst': '15', 'Wgt': '8', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Vyke's War Spear", 'Type': 'Great Spear', 'Phy': '252', 'Mag': '0', 'Fir': '161', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '122', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '(65)', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '45', 'def-Lit': '33', 'def-Hol': '33', 'Bst': '35', 'Rst': '20', 'Wgt': '8', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Wakizashi', 'Type': 'Dagger', 'Phy': '230', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '66', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(38)', 'def-Phy': '42', 'def-Mag': '24', 'def-Fir': '24', 'def-Lit': '24', 'def-Hol': '24', 'Bst': '21', 'Rst': '12', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Warhawk's Talon", 'Type': 'Straight Sword', 'Phy': '247', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '84', 'Str': 'D', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '42', 'def-Mag': '28', 'def-Fir': '28', 'def-Lit': '28', 'def-Hol': '28', 'Bst': '33', 'Rst': '14', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Warped Axe', 'Type': 'Greataxe', 'Phy': '289', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '128', 'Str': 'B', 'Dex': '0', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '56', 'def-Mag': '37', 'def-Fir': '37', 'def-Lit': '37', 'def-Hol': '37', 'Bst': '51', 'Rst': '18', 'Wgt': '7.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Warpick', 'Type': 'Hammer', 'Phy': '264', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '106', 'Str': 'D', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '40', 'def-Mag': '27', 'def-Fir': '27', 'def-Lit': '27', 'def-Hol': '27', 'Bst': '32', 'Rst': '13', 'Wgt': '2.5', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Watchdog's Greatsword", 'Type': 'Colossal Sword', 'Phy': '347', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '164', 'Str': 'B', 'Dex': 'E', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '66', 'def-Mag': '49', 'def-Fir': '49', 'def-Lit': '49', 'def-Hol': '49', 'Bst': '45', 'Rst': '27', 'Wgt': '22', 'Upgrade': 'Smithing Stones'}
# {'Weapon': "Watchdog's Staff", 'Type': 'Colossal Weapon', 'Phy': '404', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '200', 'Str': 'C', 'Dex': 'D', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '60', 'def-Mag': '45', 'def-Fir': '45', 'def-Lit': '45', 'def-Hol': '45', 'Bst': '40', 'Rst': '25', 'Wgt': '19', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Weathered Straight Sword', 'Type': 'Straight Sword', 'Phy': '252', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '90', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '43', 'def-Mag': '29', 'def-Fir': '29', 'def-Lit': '29', 'def-Hol': '29', 'Bst': '34', 'Rst': '14', 'Wgt': '3', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Whip', 'Type': 'Whip', 'Phy': '245', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '84', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '25', 'def-Mag': '15', 'def-Fir': '15', 'def-Lit': '15', 'def-Hol': '15', 'Bst': '18', 'Rst': '10', 'Wgt': '2', 'Upgrade': 'Smithing Stones'}
# {'Weapon': 'Wing of Astel', 'Type': 'Curved Sword', 'Phy': '159', 'Mag': '191', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '84', 'Str': 'E', 'Dex': 'C', 'Int': 'B', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '28', 'def-Mag': '52', 'def-Fir': '23', 'def-Lit': '23', 'def-Hol': '23', 'Bst': '23', 'Rst': '9', 'Wgt': '2.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Winged Greathorn', 'Type': 'Greataxe', 'Phy': '318', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '150', 'Str': 'C', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '50', 'def-Mag': '35', 'def-Fir': '35', 'def-Lit': '35', 'def-Hol': '35', 'Bst': '35', 'Rst': '20', 'Wgt': '11', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Winged Scythe', 'Type': 'Reaper', 'Phy': '213', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '254', 'Cri': '100', 'Sta': '110', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': 'C', 'Arc': '0', 'Any': '(55)', 'def-Phy': '30', 'def-Mag': '25', 'def-Fir': '25', 'def-Lit': '25', 'def-Hol': '55', 'Bst': '30', 'Rst': '15', 'Wgt': '7.5', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Zamor Curved Sword', 'Type': 'Curved Greatsword', 'Phy': '306', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '128', 'Str': 'C', 'Dex': 'B', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '(65)', 'def-Phy': '47', 'def-Mag': '33', 'def-Fir': '33', 'def-Lit': '33', 'def-Hol': '33', 'Bst': '33', 'Rst': '19', 'Wgt': '9', 'Upgrade': 'Somber Smithing Stones'}
# {'Weapon': 'Zweihander', 'Type': 'Colossal Sword', 'Phy': '345', 'Mag': '0', 'Fir': '0', 'Lit': '0', 'Hol': '0', 'Cri': '100', 'Sta': '126', 'Str': 'D', 'Dex': 'C', 'Int': '0', 'Fai': '0', 'Arc': '0', 'Any': '0', 'def-Phy': '54', 'def-Mag': '40', 'def-Fir': '40', 'def-Lit': '40', 'def-Hol': '40', 'Bst': '43', 'Rst': '22', 'Wgt': '15.5', 'Upgrade': 'Smithing Stones'}

# %%
collection.drop("Weapon":)
